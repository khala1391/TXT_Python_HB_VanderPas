# %% [markdown]
# ## Chapter7: aggregation function

# %% [markdown]
# ---
# * Author:  [Yuttapong Mahasittiwat](mailto:khala1391@gmail.com)
# * Technologist | Data Modeler | Data Analyst
# * [YouTube](https://www.youtube.com/khala1391)
# * [LinkedIn](https://www.linkedin.com/in/yuttapong-m/)
# ---

# %% [markdown]
# Source: [**Python Data Science Handbook** by **VanderPlas**](https://jakevdp.github.io/PythonDataScienceHandbook/)

# %%
from PIL import Image
from IPython.display import display

# %%
import numpy as np
rng = np.random.default_rng()
# Generate one random float uniformly distributed over the range [0, 1)

# %%
L = rng.random(100)
sum(L)
# Out:
# 46.534395918484506

# %%
np.sum(L)
# Out:
# 46.534395918484506

# %%
big_array = rng.random(1000000)
# %timeit sum(big_array)
# %timeit np.sum(big_array)
# Out:
# 133 ms ± 4.02 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 903 µs ± 50.1 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
sum(big_array), np.sum(big_array)
# Out:
# (499329.47962009296, 499329.4796200766)

# %% [markdown]
# ### Minimum and Maximum

# %%
min(big_array), max(big_array)
# Out:
# (2.77125321679339e-06, 0.9999958631778931)

# %%
np.min(big_array), np.max(big_array)
# Out:
# (2.77125321679339e-06, 0.9999958631778931)

# %%
# %timeit min(big_array)
# %timeit np.min(big_array)
# Out:
# 86 ms ± 4.75 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 764 µs ± 80.4 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
# shorter syntax
print(big_array.min(), big_array.max(),big_array.sum())
# Out:
# 2.82722144751002e-06 0.9999985617843742 500153.6783549102

# %% [markdown]
# ### Multidimensional Aggregates

# %%
M = rng.integers(0,10,(3,4))
M
# Out:
# array([[9, 6, 2, 0],
#        [6, 0, 4, 0],
#        [6, 5, 3, 8]], dtype=int64)

# %%
M.sum()
# Out:
# 49

# %%
M.min(axis=0)
# Out:
# array([6, 0, 2, 0], dtype=int64)

# %%
M.max(axis=1)
# Out:
# array([9, 6, 8], dtype=int64)

# %% [markdown]
# ### Other Aggregation Functions

# %%
img1 = Image.open('figure/tbl7_1a.png')
img2 = Image.open('figure/tbl7_1b.png')
display(img1)
display(img2)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=693x380>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=704x243>

# %% [markdown]
# ### example: avg height

# %%
# !head -4 data/president_heights.csv
# Out:
# order,name,height(cm)
# 1,George Washington,189
# 2,John Adams,170
# 3,Thomas Jefferson,189

# %%
import pandas as pd
data = pd.read_csv('data/president_heights.csv')
heights = np.array(data['height(cm)'])
print(heights)
# Out:
# [189 170 189 163 183 171 185 168 173 183 173 173 175 178 183 193 178 173
#  174 183 183 168 170 178 182 180 183 178 182 188 175 179 183 193 182 183
#  177 185 188 188 182 185 191 182]

# %%
print("Mean height:          ", heights.mean())
print("Standard Deviation:   ", heights.std())
print("Minimum height:       ", heights.min())
print("Maximum height:       ", heights.max())
# Out:
# Mean height:           180.04545454545453
# Standard Deviation:    6.983599441335736
# Minimum height:        163
# Maximum height:        193

# %%
print("25th percentile", np.percentile(heights,25))
print("Median", np.median(heights))
print("75th percentile", np.percentile(heights,75))
# Out:
# 25th percentile 174.75
# Median 182.0
# 75th percentile 183.5

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8-whitegrid')
# plt.style.available

# %%
plt.hist(heights)
plt.title('Height Distribution of US Presidents')
plt.xlabel('height (cm)')
plt.ylabel('number');
