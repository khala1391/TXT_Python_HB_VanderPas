# %% [markdown]
# ## Chapter8: Broadcasting

# %% [markdown]
# ---
# * Author:  [Yuttapong Mahasittiwat](mailto:khala1391@gmail.com)
# * Technologist | Data Modeler | Data Analyst
# * [YouTube](https://www.youtube.com/khala1391)
# * [LinkedIn](https://www.linkedin.com/in/yuttapong-m/)
# ---

# %% [markdown]
# Source: [**Python Data Science Handbook** by **VanderPlas**](https://jakevdp.github.io/PythonDataScienceHandbook/)

# %% [markdown]
# ### introducting Broadcasting

# %%
from PIL import Image
from IPython.display import display

# %%
import numpy as np

# %%
a = np.array([0,1,2])
b = np.array([5,5,5])
a + b
# Out:
# array([5, 6, 7])

# %%
a+5
# Out:
# array([5, 6, 7])

# %%
M = np.ones((3,3))
M
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.],
#        [1., 1., 1.]])

# %%
M + a
# Out:
# array([[1., 2., 3.],
#        [1., 2., 3.],
#        [1., 2., 3.]])

# %%
a = np.arange(3)
b = np.arange(3)[:, np.newaxis]
print(a)
print(b)
# Out:
# [0 1 2]
# [[0]
#  [1]
#  [2]]

# %%
a + b
# Out:
# array([[0, 1, 2],
#        [1, 2, 3],
#        [2, 3, 4]])

# %%
img = Image.open('figure/tbl8_1.png')
w,h = img.size
s = .6
img = img.resize((int(s*w),int(s*h)))
display(img)
# Out:
# <PIL.Image.Image image mode=RGB size=506x372>

# %% [markdown]
# ### rule of broadcasting

# %% [markdown]
# ### broadcasting in practice

# %%
rng = np.random.default_rng(seed=1701)
X = rng.random((10,3))

# %%
Xmean = X.mean(0)   # axis=0
Xmean
# Out:
# array([0.38503638, 0.36991443, 0.63896043])

# %% [markdown]
# **center an array**

# %%
X_centered = X-Xmean
X_centered.mean(0)
# Out:
# array([ 4.99600361e-17, -4.44089210e-17,  0.00000000e+00])

# %% [markdown]
# **plotting 2D**

# %%
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,5,50)
y = np.linspace(0,5,50)[:, np.newaxis]
z = np.sin(x)**10 + np.cos(10 + y*x)* np.cos(x)

# %%
plt.imshow(z, origin= 'lower', extent =[0,5,0,5])
plt.colorbar();

# %% [markdown]
# **Example2**

# %%
x = np.linspace(0,5,50)
y = np.linspace(0,5,50)[:, np.newaxis]
z = np.sin(x) + np.cos(y)

# %%
plt.imshow(z, origin= 'lower', extent =[0,5,0,5])
plt.colorbar();
