# %% [markdown]
# ## Chapter25: General Matplotlib Tips

# %% [markdown]
# ---
# * Author:  [Yuttapong Mahasittiwat](mailto:khala1391@gmail.com)
# * Technologist | Data Modeler | Data Analyst
# * [YouTube](https://www.youtube.com/khala1391)
# * [LinkedIn](https://www.linkedin.com/in/yuttapong-m/)
# ---

# %% [markdown]
# Source: [**Python Data Science Handbook** by **VanderPlas**](https://jakevdp.github.io/PythonDataScienceHandbook/)

# %%
import numpy as np
import pandas as pd
print("numpy version :",np.__version__)
print("pandas version :",pd.__version__)
# Out:
# numpy version : 1.26.4
# pandas version : 2.2.1

# %% [markdown]
# ### Importing Matplotlib

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# ### Setting Styles

# %%
# plt.style.available
plt.style.use('seaborn-v0_8-talk')

# %% [markdown]
# ### How to Display Your Plots

# %% [markdown]
# #### plotting from script

# %%
# %run data/myplot.py

# %% [markdown]
# #### plotting from ipython shell

# %% [markdown]
# #### plotting from Jupyter NB

# %%
# %matplotlib  # pop-up windows
# Out:
# Using matplotlib backend: QtAgg

# %%
x = np.linspace(0, 10, 100)

fig = plt.figure()
plt.plot(x, np.sin(x), '-')
plt.plot(x, np.cos(x), '--')
plt.show();

# %% [markdown]
# #### save figure

# %%
fig.savefig('data/my_figure.png')

# %%
# !ls -lh data/my_figure.png
# Out:
# -rw-r--r-- 1 khala khala 37K Jul 29 02:52 data/my_figure.png

# %%
# from PIL import Image   # modify image, call image
from IPython.display import display, Image  # call image

# %%
Image('data/my_figure.png')

# %%
fig.canvas.get_supported_filetypes()
# Out:
# {'eps': 'Encapsulated Postscript',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'ps': 'Postscript',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format',
#  'webp': 'WebP Image Format'}

# %% [markdown]
# #### two interface

# %% [markdown]
# ##### MATLAB-style interface

# %%
plt.figure() # create a plot figure

# create the first of two panels and set current axis
plt.subplot(2, 1, 1) # (rows, columns, panel number)
plt.plot(x, np.sin(x))

# create the second panel and set current axis
plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x));

# %% [markdown]
# ##### Object-oriented interface

# %%
# create grid for plot
fig, ax = plt.subplots(2)

# call plot for each object
ax[0].plot(x, np.sin(x))
ax[1].plot(x, np.cos(x));
